# %%
number = int(65654)

while number > 0:
    if number % 10== 7:
        print('pass')
        break
    number = number // 10
    print('number', number)
# Out:
# number 6565
# number 656
# number 65
# number 6
# number 0
