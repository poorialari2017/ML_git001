# %%
# Out:
# Filename: C:\Users\PLATMA~1\AppData\Local\Temp\bkr46CC.tmp Output file: C:\Users\PLATMA~1\AppData\Local\Temp\out46CD.tmp
# Written: 100 Context: 1930922087360
# Written: 100 Context: 1930922087360
# Written: 100 Context: 1930922087360
# Written: 100 Context: 1930922087360
# Written: 100 Context: 1930922087360
# Written: 100 Context: 1930922087360
# Written: 100 Context: 1930922087360
# Written: 100 Context: 1930922087360
# Written: 100 Context: 1930922087360
# Written: 100 Context: 1930922087360
# Written: 16 Context: 1930922087360
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 from Demos.BackupRead_BackupWrite import tempfile
# ----> 3 num1 = int(input("number one: "))
#       4 num2 = int(input("number two: "))
#       5 if num1 == num2 or num1 >= num2:
#
# ...
