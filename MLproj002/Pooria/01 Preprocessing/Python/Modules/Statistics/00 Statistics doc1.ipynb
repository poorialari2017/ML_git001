# %%
grades = [96,56,7,98,77,268,54]

# %%
#average
sum(grades)/ len(grades)
# Out:
# 93.71428571428571

# %%
import statistics

#
statistics.mean(grades)
# Out:
# 93.71428571428571

# %%
#
statistics.median(grades)
# Out:
# 77

# %%
#
statistics.mode(grades)
# Out:
# 96
