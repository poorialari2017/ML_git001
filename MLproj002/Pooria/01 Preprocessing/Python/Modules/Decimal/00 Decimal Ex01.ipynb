# %%
from decimal import Decimal
p = Decimal('1000.00')
r = Decimal('0.05')
n = Decimal('10')
n = Decimal('0')

#a = p*(r + 1)**n

# %%
for year in range(2010, 2021, 1):
    n += 1
    amount = p*(r + 1)** n
    print(f'{year:>2}{amount:>10.2f}')
# Out:
# 2010   1050.00
# 2011   1102.50
# 2012   1157.62
# 2013   1215.51
# 2014   1276.28
# 2015   1340.10
# 2016   1407.10
# 2017   1477.46
# 2018   1551.33
# 2019   1628.89
# 2020   1710.34
