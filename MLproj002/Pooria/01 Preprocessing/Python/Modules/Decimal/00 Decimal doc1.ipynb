# %%
from decimal import Decimal

# %%
a = 223.66
b = Decimal('223.66')

print(f'a = {a:.20f}')
print(f'b = {b:.20f}')
# Out:
# a = 223.65999999999999658939
# b = 223.66000000000000000000

# %%
x = Decimal('10.5')
y = Decimal('2')

# %%
x + y
# Out:
# Decimal('12.5')

# %%
x//y
# Out:
# Decimal('5')

# %%
x += y
x
# Out:
# Decimal('12.5')

# %% [markdown]
# <div dir="rtl" style="text-align: right; font-family: 'B Nazanin'; font-size: 16pt;"">
# بین اعداد
# decimal
# و صمحیح میتوان عملیات انجام داد ولی اینکار با اعداد اعشاری <strong>مجاز نیست</strong>.
# </div>
